# %% [markdown]
# # import necessery libraries

# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.model_selection import KFold

# %% [markdown]
# # Dataset loading

# %%
# Define the dataset path
dataset_path = 'dog_vs_cat_dataset/animals' 

# Set up image data generator
data_gen = ImageDataGenerator(rescale=1./255)

# Load all data into a single generator (shuffle to mix the images)
data_generator = data_gen.flow_from_directory(
    dataset_path,
    target_size=(128, 128),
    batch_size=32,
    class_mode='binary',
    shuffle=True  # Shuffle the data
)

# Load all images and labels into memory
X, y = [], []
for i in range(len(data_generator)):
    batch_data, batch_labels = data_generator[i]
    X.extend(batch_data)
    y.extend(batch_labels)
X = np.array(X)
y = np.array(y)
# Out:
# Found 1000 images belonging to 2 classes.

# %% [markdown]
# # Define the CNN model

# %%
def create_model(learning_rate):
    model = keras.Sequential([
        keras.layers.InputLayer(input_shape=(128, 128, 3)),
        
        keras.layers.Conv2D(32, (3, 3), activation='relu', padding='same'),
        keras.layers.MaxPooling2D(pool_size=(2, 2)),
        keras.layers.Dropout(0.2), 
        
        keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same'),
        keras.layers.MaxPooling2D(pool_size=(2, 2)),
        keras.layers.Dropout(0.2), 

        keras.layers.Conv2D(128, (3, 3), activation='relu', padding='same'),
        keras.layers.MaxPooling2D(pool_size=(2, 2)),
        keras.layers.Dropout(0.2), 

        keras.layers.Flatten(),
        keras.layers.Dense(512, activation='relu'),
        keras.layers.BatchNormalization(),
        keras.layers.Dropout(0.5),
        keras.layers.Dense(1, activation='sigmoid')
        
       
    ])

    model.compile(
        optimizer=keras.optimizers.Adam(learning_rate=learning_rate),
        loss='binary_crossentropy',
        metrics=['accuracy', 'Precision', 'Recall']
    )
    return model

# Perform K-Fold Cross-Validation
k = 5  # Number of folds
kf = KFold(n_splits=k, shuffle=True, random_state=42)

fold = 1
for train_index, val_index in kf.split(X):
    print(f"Training on Fold {fold}...")

    # Split the data into training and validation sets
    X_train, X_val = X[train_index], X[val_index]
    y_train, y_val = y[train_index], y[val_index]

    # Create the model
    model = create_model(learning_rate=0.001)

    # Set up early stopping
    early_stopping = EarlyStopping(patience=5, restore_best_weights=True)

    # Train the model
    history = model.fit(
        X_train, y_train,
        validation_data=(X_val, y_val),
        epochs=30,
        batch_size=32,
        callbacks=[early_stopping]
    )

    # Evaluate the model on the validation set
    val_loss, val_accuracy, val_precision, val_recall = model.evaluate(X_val, y_val)
    print(f"Fold {fold} - Validation Loss: {val_loss}, Accuracy: {val_accuracy}, Precision: {val_precision}, Recall: {val_recall}")
    
    fold += 1
# Out:
# Training on Fold 1...
# C:\Users\asmaa\anaconda3\Lib\site-packages\keras\src\layers\core\input_layer.py:26: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(
# Epoch 1/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 16s 412ms/step - Precision: 0.7076 - Recall: 0.6873 - accuracy: 0.6920 - loss: 0.7956 - val_Precision: 0.4600 - val_Recall: 1.0000 - val_accuracy: 0.4600 - val_loss: 1.6579
# Epoch 2/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 361ms/step - Precision: 0.8015 - Recall: 0.7892 - accuracy: 0.7938 - loss: 0.4408 - val_Precision: 0.5412 - val_Recall: 1.0000 - val_accuracy: 0.6100 - val_loss: 0.6143
# Epoch 3/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 358ms/step - Precision: 0.8650 - Recall: 0.8641 - accuracy: 0.8634 - loss: 0.3161 - val_Precision: 0.9348 - val_Recall: 0.4674 - val_accuracy: 0.7400 - val_loss: 0.4768
# Epoch 4/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 379ms/step - Precision: 0.8992 - Recall: 0.9050 - accuracy: 0.9024 - loss: 0.2107 - val_Precision: 1.0000 - val_Recall: 0.4565 - val_accuracy: 0.7500 - val_loss: 0.3938
# Epoch 5/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 367ms/step - Precision: 0.9842 - Recall: 0.9227 - accuracy: 0.9510 - loss: 0.1376 - val_Precision: 1.0000 - val_Recall: 0.1196 - val_accuracy: 0.5950 - val_loss: 0.7299
# Epoch 6/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 392ms/step - Precision: 0.9771 - Recall: 0.9593 - accuracy: 0.9685 - loss: 0.0726 - val_Precision: 1.0000 - val_Recall: 0.3804 - val_accuracy: 0.7150 - val_loss: 0.4771
# Epoch 7/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 374ms/step - Precision: 0.9923 - Recall: 0.9725 - accuracy: 0.9806 - loss: 0.0492 - val_Precision: 1.0000 - val_Recall: 0.0543 - val_accuracy: 0.5650 - val_loss: 1.0918
# Epoch 8/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 387ms/step - Precision: 0.9889 - Recall: 0.9955 - accuracy: 0.9926 - loss: 0.0313 - val_Precision: 1.0000 - val_Recall: 0.5109 - val_accuracy: 0.7750 - val_loss: 0.3965
# Epoch 9/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 377ms/step - Precision: 0.9995 - Recall: 0.9920 - accuracy: 0.9956 - loss: 0.0231 - val_Precision: 0.9889 - val_Recall: 0.9674 - val_accuracy: 0.9800 - val_loss: 0.0846
# Epoch 10/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 391ms/step - Precision: 0.9945 - Recall: 0.9918 - accuracy: 0.9933 - loss: 0.0244 - val_Precision: 1.0000 - val_Recall: 0.5000 - val_accuracy: 0.7700 - val_loss: 0.4896
# Epoch 11/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 407ms/step - Precision: 0.9970 - Recall: 1.0000 - accuracy: 0.9985 - loss: 0.0113 - val_Precision: 0.9293 - val_Recall: 1.0000 - val_accuracy: 0.9650 - val_loss: 0.1005
# Epoch 12/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 385ms/step - Precision: 0.9954 - Recall: 0.9911 - accuracy: 0.9926 - loss: 0.0196 - val_Precision: 1.0000 - val_Recall: 0.8804 - val_accuracy: 0.9450 - val_loss: 0.1344
# Epoch 13/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 390ms/step - Precision: 0.9965 - Recall: 0.9981 - accuracy: 0.9973 - loss: 0.0112 - val_Precision: 1.0000 - val_Recall: 0.5761 - val_accuracy: 0.8050 - val_loss: 0.5482
# Epoch 14/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 390ms/step - Precision: 0.9793 - Recall: 0.9918 - accuracy: 0.9853 - loss: 0.0293 - val_Precision: 0.7541 - val_Recall: 1.0000 - val_accuracy: 0.8500 - val_loss: 0.3395
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 96ms/step - Precision: 0.9921 - Recall: 0.9690 - accuracy: 0.9815 - loss: 0.0856
# Fold 1 - Validation Loss: 0.08457807451486588, Accuracy: 0.9800000190734863, Precision: 0.9888888597488403, Recall: 0.967391312122345
# Training on Fold 2...
# Epoch 1/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 62s 917ms/step - Precision: 0.6516 - Recall: 0.6759 - accuracy: 0.6590 - loss: 0.8854 - val_Precision: 0.6077 - val_Recall: 1.0000 - val_accuracy: 0.6450 - val_loss: 0.5991
# Epoch 2/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 21s 816ms/step - Precision: 0.7797 - Recall: 0.7599 - accuracy: 0.7717 - loss: 0.5720 - val_Precision: 0.9579 - val_Recall: 0.8273 - val_accuracy: 0.8850 - val_loss: 0.3810
# Epoch 3/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 21s 810ms/step - Precision: 0.8835 - Recall: 0.8397 - accuracy: 0.8653 - loss: 0.3388 - val_Precision: 0.9266 - val_Recall: 0.9182 - val_accuracy: 0.9150 - val_loss: 0.2859
# Epoch 4/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 20s 772ms/step - Precision: 0.9061 - Recall: 0.8889 - accuracy: 0.8986 - loss: 0.2249 - val_Precision: 0.8088 - val_Recall: 1.0000 - val_accuracy: 0.8700 - val_loss: 0.3178
# Epoch 5/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 20s 789ms/step - Precision: 0.9121 - Recall: 0.9278 - accuracy: 0.9257 - loss: 0.1993 - val_Precision: 0.9810 - val_Recall: 0.9364 - val_accuracy: 0.9550 - val_loss: 0.1891
# Epoch 6/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 21s 819ms/step - Precision: 0.9783 - Recall: 0.9545 - accuracy: 0.9672 - loss: 0.0885 - val_Precision: 0.7285 - val_Recall: 1.0000 - val_accuracy: 0.7950 - val_loss: 0.4213
# Epoch 7/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 19s 749ms/step - Precision: 0.9853 - Recall: 0.9711 - accuracy: 0.9771 - loss: 0.0725 - val_Precision: 0.9901 - val_Recall: 0.9091 - val_accuracy: 0.9450 - val_loss: 0.1584
# Epoch 8/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 19s 741ms/step - Precision: 0.9960 - Recall: 0.9850 - accuracy: 0.9907 - loss: 0.0312 - val_Precision: 0.9818 - val_Recall: 0.9818 - val_accuracy: 0.9800 - val_loss: 0.0913
# Epoch 9/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 19s 761ms/step - Precision: 0.9939 - Recall: 0.9816 - accuracy: 0.9867 - loss: 0.0380 - val_Precision: 0.9244 - val_Recall: 1.0000 - val_accuracy: 0.9550 - val_loss: 0.1009
# Epoch 10/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 19s 736ms/step - Precision: 0.9794 - Recall: 0.9990 - accuracy: 0.9897 - loss: 0.0438 - val_Precision: 1.0000 - val_Recall: 0.7727 - val_accuracy: 0.8750 - val_loss: 0.2737
# Epoch 11/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 20s 795ms/step - Precision: 0.9741 - Recall: 0.9880 - accuracy: 0.9823 - loss: 0.0652 - val_Precision: 0.9820 - val_Recall: 0.9909 - val_accuracy: 0.9850 - val_loss: 0.0562
# Epoch 12/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 21s 817ms/step - Precision: 0.9939 - Recall: 0.9944 - accuracy: 0.9942 - loss: 0.0205 - val_Precision: 0.9909 - val_Recall: 0.9909 - val_accuracy: 0.9900 - val_loss: 0.0462
# Epoch 13/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 21s 820ms/step - Precision: 0.9899 - Recall: 0.9997 - accuracy: 0.9949 - loss: 0.0128 - val_Precision: 1.0000 - val_Recall: 0.9636 - val_accuracy: 0.9800 - val_loss: 0.0568
# Epoch 14/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 21s 817ms/step - Precision: 0.9992 - Recall: 0.9997 - accuracy: 0.9995 - loss: 0.0102 - val_Precision: 1.0000 - val_Recall: 0.9636 - val_accuracy: 0.9800 - val_loss: 0.0446
# Epoch 15/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 18s 729ms/step - Precision: 1.0000 - Recall: 1.0000 - accuracy: 1.0000 - loss: 0.0056 - val_Precision: 0.9907 - val_Recall: 0.9727 - val_accuracy: 0.9800 - val_loss: 0.0405
# Epoch 16/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 12s 451ms/step - Precision: 0.9990 - Recall: 1.0000 - accuracy: 0.9995 - loss: 0.0072 - val_Precision: 1.0000 - val_Recall: 0.9091 - val_accuracy: 0.9500 - val_loss: 0.1213
# Epoch 17/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 392ms/step - Precision: 0.9966 - Recall: 0.9907 - accuracy: 0.9932 - loss: 0.0240 - val_Precision: 0.8209 - val_Recall: 1.0000 - val_accuracy: 0.8800 - val_loss: 0.3893
# Epoch 18/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 379ms/step - Precision: 0.9993 - Recall: 0.9931 - accuracy: 0.9962 - loss: 0.0138 - val_Precision: 0.9402 - val_Recall: 1.0000 - val_accuracy: 0.9650 - val_loss: 0.0896
# Epoch 19/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 395ms/step - Precision: 0.9879 - Recall: 0.9838 - accuracy: 0.9865 - loss: 0.0333 - val_Precision: 1.0000 - val_Recall: 0.9636 - val_accuracy: 0.9800 - val_loss: 0.0725
# Epoch 20/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 19s 777ms/step - Precision: 0.9936 - Recall: 0.9887 - accuracy: 0.9914 - loss: 0.0304 - val_Precision: 0.7639 - val_Recall: 1.0000 - val_accuracy: 0.8300 - val_loss: 0.5771
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - Precision: 0.9911 - Recall: 0.9695 - accuracy: 0.9776 - loss: 0.0387
# Fold 2 - Validation Loss: 0.04049786552786827, Accuracy: 0.9800000190734863, Precision: 0.9907407164573669, Recall: 0.9727272987365723
# Training on Fold 3...
# Epoch 1/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - Precision: 0.6608 - Recall: 0.6578 - accuracy: 0.6425 - loss: 0.8716 - val_Precision: 0.8028 - val_Recall: 0.6264 - val_accuracy: 0.7600 - val_loss: 0.5313
# Epoch 2/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 35s 746ms/step - Precision: 0.8418 - Recall: 0.8052 - accuracy: 0.8228 - loss: 0.3940 - val_Precision: 0.4787 - val_Recall: 0.9890 - val_accuracy: 0.5050 - val_loss: 0.7850
# Epoch 3/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 19s 778ms/step - Precision: 0.8826 - Recall: 0.8379 - accuracy: 0.8539 - loss: 0.3011 - val_Precision: 0.7016 - val_Recall: 0.9560 - val_accuracy: 0.7950 - val_loss: 0.4512
# Epoch 4/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 17s 663ms/step - Precision: 0.9206 - Recall: 0.8759 - accuracy: 0.8943 - loss: 0.2652 - val_Precision: 1.0000 - val_Recall: 0.3297 - val_accuracy: 0.6950 - val_loss: 0.6428
# Epoch 5/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 18s 705ms/step - Precision: 0.9687 - Recall: 0.9350 - accuracy: 0.9487 - loss: 0.1643 - val_Precision: 0.9730 - val_Recall: 0.3956 - val_accuracy: 0.7200 - val_loss: 0.5183
# Epoch 6/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 20s 790ms/step - Precision: 0.9794 - Recall: 0.9649 - accuracy: 0.9693 - loss: 0.0868 - val_Precision: 0.9818 - val_Recall: 0.5934 - val_accuracy: 0.8100 - val_loss: 0.3482
# Epoch 7/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 20s 811ms/step - Precision: 0.9789 - Recall: 0.9509 - accuracy: 0.9628 - loss: 0.0858 - val_Precision: 0.9271 - val_Recall: 0.9780 - val_accuracy: 0.9550 - val_loss: 0.1698
# Epoch 8/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 20s 783ms/step - Precision: 0.9945 - Recall: 0.9855 - accuracy: 0.9891 - loss: 0.0600 - val_Precision: 0.9535 - val_Recall: 0.9011 - val_accuracy: 0.9350 - val_loss: 0.1342
# Epoch 9/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 19s 730ms/step - Precision: 0.9948 - Recall: 0.9845 - accuracy: 0.9889 - loss: 0.0283 - val_Precision: 0.6067 - val_Recall: 1.0000 - val_accuracy: 0.7050 - val_loss: 0.5468
# Epoch 10/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 20s 788ms/step - Precision: 0.9923 - Recall: 0.9916 - accuracy: 0.9919 - loss: 0.0274 - val_Precision: 0.9853 - val_Recall: 0.7363 - val_accuracy: 0.8750 - val_loss: 0.2272
# Epoch 11/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 19s 763ms/step - Precision: 0.9869 - Recall: 0.9859 - accuracy: 0.9869 - loss: 0.0321 - val_Precision: 0.9677 - val_Recall: 0.9890 - val_accuracy: 0.9800 - val_loss: 0.1151
# Epoch 12/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 19s 754ms/step - Precision: 0.9961 - Recall: 0.9809 - accuracy: 0.9884 - loss: 0.0257 - val_Precision: 0.9625 - val_Recall: 0.8462 - val_accuracy: 0.9150 - val_loss: 0.1769
# Epoch 13/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 466ms/step - Precision: 0.9837 - Recall: 0.9781 - accuracy: 0.9797 - loss: 0.0583 - val_Precision: 0.7913 - val_Recall: 1.0000 - val_accuracy: 0.8800 - val_loss: 0.3056
# Epoch 14/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 382ms/step - Precision: 0.9926 - Recall: 1.0000 - accuracy: 0.9962 - loss: 0.0185 - val_Precision: 0.9770 - val_Recall: 0.9341 - val_accuracy: 0.9600 - val_loss: 0.0910
# Epoch 15/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 376ms/step - Precision: 1.0000 - Recall: 1.0000 - accuracy: 1.0000 - loss: 0.0073 - val_Precision: 0.9681 - val_Recall: 1.0000 - val_accuracy: 0.9850 - val_loss: 0.0657
# Epoch 16/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 383ms/step - Precision: 0.9956 - Recall: 0.9969 - accuracy: 0.9963 - loss: 0.0184 - val_Precision: 0.9875 - val_Recall: 0.8681 - val_accuracy: 0.9350 - val_loss: 0.1585
# Epoch 17/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 18s 743ms/step - Precision: 0.9942 - Recall: 0.9994 - accuracy: 0.9969 - loss: 0.0096 - val_Precision: 0.9579 - val_Recall: 1.0000 - val_accuracy: 0.9800 - val_loss: 0.0858
# Epoch 18/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 15s 584ms/step - Precision: 0.9926 - Recall: 0.9941 - accuracy: 0.9931 - loss: 0.0195 - val_Precision: 1.0000 - val_Recall: 0.7692 - val_accuracy: 0.8950 - val_loss: 0.2218
# Epoch 19/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 20s 807ms/step - Precision: 0.9919 - Recall: 0.9832 - accuracy: 0.9872 - loss: 0.0346 - val_Precision: 0.7583 - val_Recall: 1.0000 - val_accuracy: 0.8550 - val_loss: 0.4015
# Epoch 20/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 21s 788ms/step - Precision: 1.0000 - Recall: 1.0000 - accuracy: 1.0000 - loss: 0.0073 - val_Precision: 0.9780 - val_Recall: 0.9780 - val_accuracy: 0.9800 - val_loss: 0.0520
# Epoch 21/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 20s 785ms/step - Precision: 1.0000 - Recall: 1.0000 - accuracy: 1.0000 - loss: 0.0021 - val_Precision: 0.9100 - val_Recall: 1.0000 - val_accuracy: 0.9550 - val_loss: 0.1148
# Epoch 22/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 17s 689ms/step - Precision: 1.0000 - Recall: 1.0000 - accuracy: 1.0000 - loss: 0.0031 - val_Precision: 0.9780 - val_Recall: 0.9780 - val_accuracy: 0.9800 - val_loss: 0.0640
# Epoch 23/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 18s 695ms/step - Precision: 0.9986 - Recall: 1.0000 - accuracy: 0.9993 - loss: 0.0078 - val_Precision: 1.0000 - val_Recall: 0.4835 - val_accuracy: 0.7650 - val_loss: 0.7254
# Epoch 24/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 17s 679ms/step - Precision: 1.0000 - Recall: 0.9997 - accuracy: 0.9999 - loss: 0.0077 - val_Precision: 0.9286 - val_Recall: 1.0000 - val_accuracy: 0.9650 - val_loss: 0.1298
# Epoch 25/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 19s 736ms/step - Precision: 0.9416 - Recall: 0.9912 - accuracy: 0.9670 - loss: 0.0872 - val_Precision: 0.9286 - val_Recall: 1.0000 - val_accuracy: 0.9650 - val_loss: 0.0950
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 187ms/step - Precision: 0.9659 - Recall: 0.9749 - accuracy: 0.9723 - loss: 0.0721
# Fold 3 - Validation Loss: 0.05196678638458252, Accuracy: 0.9800000190734863, Precision: 0.9780219793319702, Recall: 0.9780219793319702
# Training on Fold 4...
# Epoch 1/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 71s 999ms/step - Precision: 0.6475 - Recall: 0.6541 - accuracy: 0.6441 - loss: 0.8189 - val_Precision: 0.7532 - val_Recall: 0.5918 - val_accuracy: 0.7050 - val_loss: 0.6062
# Epoch 2/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 18s 728ms/step - Precision: 0.7643 - Recall: 0.7511 - accuracy: 0.7570 - loss: 0.5321 - val_Precision: 0.6507 - val_Recall: 0.9694 - val_accuracy: 0.7300 - val_loss: 0.5532
# Epoch 3/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 20s 778ms/step - Precision: 0.8756 - Recall: 0.8254 - accuracy: 0.8458 - loss: 0.3571 - val_Precision: 0.9079 - val_Recall: 0.7041 - val_accuracy: 0.8200 - val_loss: 0.3728
# Epoch 4/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 22s 790ms/step - Precision: 0.9077 - Recall: 0.9196 - accuracy: 0.9080 - loss: 0.2114 - val_Precision: 0.9403 - val_Recall: 0.6429 - val_accuracy: 0.8050 - val_loss: 0.4159
# Epoch 5/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 20s 805ms/step - Precision: 0.9442 - Recall: 0.9485 - accuracy: 0.9447 - loss: 0.1339 - val_Precision: 0.8364 - val_Recall: 0.9388 - val_accuracy: 0.8800 - val_loss: 0.3429
# Epoch 6/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 12s 449ms/step - Precision: 0.9746 - Recall: 0.9693 - accuracy: 0.9726 - loss: 0.0874 - val_Precision: 0.9855 - val_Recall: 0.6939 - val_accuracy: 0.8450 - val_loss: 0.3209
# Epoch 7/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 349ms/step - Precision: 0.9783 - Recall: 0.9770 - accuracy: 0.9765 - loss: 0.0654 - val_Precision: 1.0000 - val_Recall: 0.1939 - val_accuracy: 0.6050 - val_loss: 1.4212
# Epoch 8/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 373ms/step - Precision: 0.9962 - Recall: 0.9799 - accuracy: 0.9880 - loss: 0.0427 - val_Precision: 0.9765 - val_Recall: 0.8469 - val_accuracy: 0.9150 - val_loss: 0.2050
# Epoch 9/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 370ms/step - Precision: 0.9864 - Recall: 0.9937 - accuracy: 0.9900 - loss: 0.0284 - val_Precision: 0.9620 - val_Recall: 0.7755 - val_accuracy: 0.8750 - val_loss: 0.2774
# Epoch 10/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 17s 697ms/step - Precision: 0.9997 - Recall: 0.9921 - accuracy: 0.9958 - loss: 0.0189 - val_Precision: 0.9565 - val_Recall: 0.8980 - val_accuracy: 0.9300 - val_loss: 0.1628
# Epoch 11/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 11s 416ms/step - Precision: 0.9939 - Recall: 0.9958 - accuracy: 0.9949 - loss: 0.0247 - val_Precision: 1.0000 - val_Recall: 0.5102 - val_accuracy: 0.7600 - val_loss: 0.6386
# Epoch 12/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 362ms/step - Precision: 1.0000 - Recall: 0.9978 - accuracy: 0.9989 - loss: 0.0136 - val_Precision: 0.9872 - val_Recall: 0.7857 - val_accuracy: 0.8900 - val_loss: 0.3204
# Epoch 13/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 11s 462ms/step - Precision: 0.9984 - Recall: 0.9990 - accuracy: 0.9987 - loss: 0.0115 - val_Precision: 0.9406 - val_Recall: 0.9694 - val_accuracy: 0.9550 - val_loss: 0.1269
# Epoch 14/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 19s 734ms/step - Precision: 0.9942 - Recall: 0.9945 - accuracy: 0.9941 - loss: 0.0174 - val_Precision: 0.9762 - val_Recall: 0.8367 - val_accuracy: 0.9100 - val_loss: 0.1844
# Epoch 15/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 22s 769ms/step - Precision: 0.9965 - Recall: 0.9903 - accuracy: 0.9932 - loss: 0.0189 - val_Precision: 0.9688 - val_Recall: 0.9490 - val_accuracy: 0.9600 - val_loss: 0.1088
# Epoch 16/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 18s 726ms/step - Precision: 0.9982 - Recall: 1.0000 - accuracy: 0.9991 - loss: 0.0066 - val_Precision: 0.9681 - val_Recall: 0.9286 - val_accuracy: 0.9500 - val_loss: 0.1204
# Epoch 17/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 21s 726ms/step - Precision: 0.9995 - Recall: 0.9975 - accuracy: 0.9985 - loss: 0.0079 - val_Precision: 0.9885 - val_Recall: 0.8776 - val_accuracy: 0.9350 - val_loss: 0.1658
# Epoch 18/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 17s 673ms/step - Precision: 1.0000 - Recall: 0.9996 - accuracy: 0.9998 - loss: 0.0044 - val_Precision: 0.9881 - val_Recall: 0.8469 - val_accuracy: 0.9200 - val_loss: 0.2594
# Epoch 19/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 21s 831ms/step - Precision: 0.9951 - Recall: 0.9955 - accuracy: 0.9953 - loss: 0.0134 - val_Precision: 0.9592 - val_Recall: 0.9592 - val_accuracy: 0.9600 - val_loss: 0.1342
# Epoch 20/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 20s 777ms/step - Precision: 0.9822 - Recall: 0.9979 - accuracy: 0.9909 - loss: 0.0180 - val_Precision: 0.9412 - val_Recall: 0.9796 - val_accuracy: 0.9600 - val_loss: 0.1345
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 155ms/step - Precision: 0.9563 - Recall: 0.9547 - accuracy: 0.9575 - loss: 0.1192
# Fold 4 - Validation Loss: 0.10881250351667404, Accuracy: 0.9599999785423279, Precision: 0.96875, Recall: 0.9489796161651611
# Training on Fold 5...
# Epoch 1/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 73s 1s/step - Precision: 0.6413 - Recall: 0.6573 - accuracy: 0.6673 - loss: 0.9468 - val_Precision: 0.7609 - val_Recall: 0.9633 - val_accuracy: 0.8150 - val_loss: 0.4705
# Epoch 2/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 20s 780ms/step - Precision: 0.8470 - Recall: 0.8259 - accuracy: 0.8375 - loss: 0.4079 - val_Precision: 0.7171 - val_Recall: 1.0000 - val_accuracy: 0.7850 - val_loss: 0.4075
# Epoch 3/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 21s 782ms/step - Precision: 0.8913 - Recall: 0.8972 - accuracy: 0.8986 - loss: 0.2507 - val_Precision: 0.7698 - val_Recall: 0.9817 - val_accuracy: 0.8300 - val_loss: 0.3915
# Epoch 4/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 18s 718ms/step - Precision: 0.9332 - Recall: 0.9177 - accuracy: 0.9260 - loss: 0.1985 - val_Precision: 0.9612 - val_Recall: 0.9083 - val_accuracy: 0.9300 - val_loss: 0.2604
# Epoch 5/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 17s 661ms/step - Precision: 0.9641 - Recall: 0.9620 - accuracy: 0.9647 - loss: 0.0939 - val_Precision: 0.8106 - val_Recall: 0.9817 - val_accuracy: 0.8650 - val_loss: 0.2968
# Epoch 6/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 391ms/step - Precision: 0.9669 - Recall: 0.9783 - accuracy: 0.9727 - loss: 0.0916 - val_Precision: 1.0000 - val_Recall: 0.4862 - val_accuracy: 0.7200 - val_loss: 0.5067
# Epoch 7/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 393ms/step - Precision: 0.9861 - Recall: 0.9862 - accuracy: 0.9856 - loss: 0.0559 - val_Precision: 0.9792 - val_Recall: 0.8624 - val_accuracy: 0.9150 - val_loss: 0.2081
# Epoch 8/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 390ms/step - Precision: 0.9992 - Recall: 0.9852 - accuracy: 0.9927 - loss: 0.0340 - val_Precision: 1.0000 - val_Recall: 0.6055 - val_accuracy: 0.7850 - val_loss: 0.4137
# Epoch 9/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 13s 502ms/step - Precision: 0.9979 - Recall: 0.9722 - accuracy: 0.9844 - loss: 0.0488 - val_Precision: 1.0000 - val_Recall: 0.5229 - val_accuracy: 0.7400 - val_loss: 0.5448
# Epoch 10/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 17s 639ms/step - Precision: 0.9961 - Recall: 0.9928 - accuracy: 0.9946 - loss: 0.0159 - val_Precision: 0.9898 - val_Recall: 0.8899 - val_accuracy: 0.9350 - val_loss: 0.1468
# Epoch 11/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 19s 758ms/step - Precision: 0.9990 - Recall: 0.9809 - accuracy: 0.9894 - loss: 0.0301 - val_Precision: 0.9890 - val_Recall: 0.8257 - val_accuracy: 0.9000 - val_loss: 0.2085
# Epoch 12/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 19s 728ms/step - Precision: 0.9875 - Recall: 0.9954 - accuracy: 0.9921 - loss: 0.0245 - val_Precision: 1.0000 - val_Recall: 0.7431 - val_accuracy: 0.8600 - val_loss: 0.2966
# Epoch 13/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 20s 778ms/step - Precision: 0.9969 - Recall: 0.9954 - accuracy: 0.9962 - loss: 0.0122 - val_Precision: 1.0000 - val_Recall: 0.8624 - val_accuracy: 0.9250 - val_loss: 0.1964
# Epoch 14/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 20s 808ms/step - Precision: 1.0000 - Recall: 1.0000 - accuracy: 1.0000 - loss: 0.0061 - val_Precision: 1.0000 - val_Recall: 0.9358 - val_accuracy: 0.9650 - val_loss: 0.1132
# Epoch 15/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 20s 793ms/step - Precision: 1.0000 - Recall: 0.9969 - accuracy: 0.9985 - loss: 0.0061 - val_Precision: 1.0000 - val_Recall: 0.8624 - val_accuracy: 0.9250 - val_loss: 0.2332
# Epoch 16/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 19s 753ms/step - Precision: 0.9980 - Recall: 0.9992 - accuracy: 0.9986 - loss: 0.0074 - val_Precision: 1.0000 - val_Recall: 0.5872 - val_accuracy: 0.7750 - val_loss: 0.6546
# Epoch 17/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 20s 779ms/step - Precision: 1.0000 - Recall: 0.9987 - accuracy: 0.9994 - loss: 0.0057 - val_Precision: 1.0000 - val_Recall: 0.9633 - val_accuracy: 0.9800 - val_loss: 0.0924
# Epoch 18/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 20s 805ms/step - Precision: 1.0000 - Recall: 0.9977 - accuracy: 0.9989 - loss: 0.0057 - val_Precision: 1.0000 - val_Recall: 0.5413 - val_accuracy: 0.7500 - val_loss: 0.8742
# Epoch 19/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 20s 786ms/step - Precision: 0.9981 - Recall: 1.0000 - accuracy: 0.9991 - loss: 0.0049 - val_Precision: 0.9474 - val_Recall: 0.9908 - val_accuracy: 0.9650 - val_loss: 0.0953
# Epoch 20/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 21s 826ms/step - Precision: 1.0000 - Recall: 1.0000 - accuracy: 1.0000 - loss: 0.0047 - val_Precision: 1.0000 - val_Recall: 0.7798 - val_accuracy: 0.8800 - val_loss: 0.3268
# Epoch 21/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 20s 781ms/step - Precision: 0.9971 - Recall: 0.9973 - accuracy: 0.9972 - loss: 0.0124 - val_Precision: 0.9881 - val_Recall: 0.7615 - val_accuracy: 0.8650 - val_loss: 0.5116
# Epoch 22/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 20s 793ms/step - Precision: 1.0000 - Recall: 0.9925 - accuracy: 0.9966 - loss: 0.0162 - val_Precision: 0.9815 - val_Recall: 0.9725 - val_accuracy: 0.9750 - val_loss: 0.0923
# Epoch 23/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 20s 787ms/step - Precision: 1.0000 - Recall: 1.0000 - accuracy: 1.0000 - loss: 0.0028 - val_Precision: 0.9811 - val_Recall: 0.9541 - val_accuracy: 0.9650 - val_loss: 0.1463
# Epoch 24/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 19s 761ms/step - Precision: 1.0000 - Recall: 1.0000 - accuracy: 1.0000 - loss: 0.0043 - val_Precision: 1.0000 - val_Recall: 0.9358 - val_accuracy: 0.9650 - val_loss: 0.1118
# Epoch 25/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 21s 762ms/step - Precision: 0.9987 - Recall: 0.9987 - accuracy: 0.9987 - loss: 0.0059 - val_Precision: 1.0000 - val_Recall: 0.3303 - val_accuracy: 0.6350 - val_loss: 1.9749
# Epoch 26/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 20s 774ms/step - Precision: 0.9856 - Recall: 0.9992 - accuracy: 0.9926 - loss: 0.0182 - val_Precision: 1.0000 - val_Recall: 0.8349 - val_accuracy: 0.9100 - val_loss: 0.3505
# Epoch 27/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 21s 825ms/step - Precision: 1.0000 - Recall: 0.9938 - accuracy: 0.9969 - loss: 0.0119 - val_Precision: 0.9231 - val_Recall: 0.9908 - val_accuracy: 0.9500 - val_loss: 0.1633
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 169ms/step - Precision: 0.9881 - Recall: 0.9706 - accuracy: 0.9781 - loss: 0.0997
# Fold 5 - Validation Loss: 0.09234807640314102, Accuracy: 0.9750000238418579, Precision: 0.9814814925193787, Recall: 0.9724770784378052
